# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import preprocessing
import sklearn.metrics as metrics
from sklearn.preprocessing import MinMaxScaler
import seaborn as seabornInstance 
from math import sqrt
xy = np.loadtxt('airfoil_self_noise.dat', delimiter = '\t',dtype = np.float32)

x_data = xy[:, 0:-1]

S = xy[:, [-1]]
D = preprocessing.normalize(x_data, norm='l2')
train_x_data, test_x_data, train_y_data, test_y_data = train_test_split(D, S, test_size = 0.2, random_state=42) 

#make sure the shape and data are OK
# print(train_x_data)
# print(train_y_data)
# print(test_x_data)
# print(test_y_data)


# plt.figure(figsize=(15,10))
# plt.tight_layout()
# seabornInstance.distplot(train_y_data)

# plt.scatter(train_x_data[:, 4:5], train_y_data,  color='black')
# plt.plot(diabetes_X_test, diabetes_y_pred, color='blue', linewidth=3)
# plt.xticks(())
# plt.yticks(())
# plt.show()

X = tf.placeholder(tf.float32, shape = [None, 5])
Y = tf.placeholder(tf.float32, shape = [None, 1])

W = tf.Variable(tf.random_normal([5,1]), name = 'weight')
b = tf.Variable(tf.random_normal([1]), name = 'bias')

hypothesis = tf.matmul(X, W) + b
cost = tf.reduce_mean(tf.square(hypothesis - Y)) + (0.001 * tf.reduce_sum(tf.square(W)))
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.5)
train = optimizer.minimize(cost)


sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(10001) : 
    cost_val, hy_val, _= sess.run([cost, hypothesis, train], feed_dict= {X: train_x_data,Y: train_y_data})
#     if step %1000 ==0:
#         print(step, "Cost: ", cost_val, "\nPrediction: \n", hy_val)
        
y_predicted = sess.run(hypothesis, feed_dict = {X:test_x_data})
y_predict = sess.run(hypothesis, feed_dict = {X:train_x_data})

print('1Mean Absolute Error:', metrics.mean_absolute_error(train_y_data, y_predict))
print('1Mean Squared Error:', metrics.mean_squared_error(train_y_data, y_predict))
print('1Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(train_y_data, y_predict)))
print()
print('2Mean Absolute Error:', metrics.mean_absolute_error(test_y_data, y_predicted))
print('2Mean Squared Error:', metrics.mean_squared_error(test_y_data, y_predicted))
print('2Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(test_y_data, y_predicted)))
# Out:
# 1Mean Absolute Error: 5.3969207
# 1Mean Squared Error: 44.12998
# 1Root Mean Squared Error: 6.6430397
#
# 2Mean Absolute Error: 5.628875
# 2Mean Squared Error: 47.990116
# 2Root Mean Squared Error: 6.9274898

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn import metrics
# %matplotlib inline

xy = np.loadtxt('airfoil_self_noise.dat', delimiter = '\t',dtype = np.float32)

x_data = xy[:, 0:-1]
Y = xy[:, [-1]]
X = preprocessing.normalize(x_data, norm='l2')
train_x_data, test_x_data, train_y_data, test_y_data = train_test_split(X, Y, test_size = 0.2, random_state=42) 

ridgeReg = Ridge(alpha = 1e-5)
ridgeReg.fit(train_x_data,train_y_data)

y_pred =ridgeReg.predict(test_x_data)
y_predicted= ridgeReg.predict(train_x_data)

print('1Mean Absolute Error:', metrics.mean_absolute_error(train_y_data, y_predicted))
print('1Mean Squared Error:', metrics.mean_squared_error(train_y_data, y_predicted))
print('1Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(train_y_data, y_predicted)))
print()
print('Mean Absolute Error:', metrics.mean_absolute_error(test_y_data, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(test_y_data, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(test_y_data, y_pred)))
# Out:
# 1Mean Absolute Error: 4.9784937
# 1Mean Squared Error: 37.887863
# 1Root Mean Squared Error: 6.1553116
#
# Mean Absolute Error: 5.452747
# Mean Squared Error: 45.80047
# Root Mean Squared Error: 6.7676044

# %%
import tensorflow as tf
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import Lasso
from sklearn import metrics
from sklearn import preprocessing

# %matplotlib inline



xy = np.loadtxt('airfoil_self_noise.dat', delimiter = '\t',dtype = np.float32)

x_data = xy[:, 0:-1]

Y = xy[:, [-1]]
X = preprocessing.normalize(x_data, norm='l2')
train_x_data, test_x_data, train_y_data, test_y_data = train_test_split(X, Y, test_size = 0.2, random_state=42) 



lassoReg = Lasso(alpha=1e-5)
lassoReg.fit(train_x_data ,train_y_data)

y_pred =lassoReg.predict(test_x_data)
y_predicted= lassoReg.predict(train_x_data)

print('1Mean Absolute Error:', metrics.mean_absolute_error(train_y_data, y_predicted))
print('1Mean Squared Error:', metrics.mean_squared_error(train_y_data, y_predicted))
print('1Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(train_y_data, y_predicted)))
print()

print('Mean Absolute Error:', metrics.mean_absolute_error(test_y_data, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(test_y_data, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(test_y_data, y_pred)))
# Out:
# 1Mean Absolute Error: 4.977851
# 1Mean Squared Error: 37.777927
# 1Root Mean Squared Error: 6.146375
#
# Mean Absolute Error: 5.4492044
# Mean Squared Error: 45.574867
# Root Mean Squared Error: 6.750916
