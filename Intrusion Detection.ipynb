# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder

def convert(data):
    number = preprocessing.LabelEncoder()
    data['protocol_type'] = number.fit_transform(data['protocol_type'])
    data['service'] = number.fit_transform(data['service'])
    data['src_bytes'] = number.fit_transform(data['src_bytes'])
    data = data.fillna(-999)
    return data



df = pd.read_csv('/home/jinho/Desktop/work/jinho/Learning_ML/dataset/kdd/kddcup.data_10_percent_corrected', names = ['duration','protocol_type','service','src_bytes','dst_bytes','flag','land','wrong_fragment','urgent',
'hot','num_failed_logins','logged_in','num_compromised','root_shell','su_attempted','num_root','num_file_creations',
'num_shells','num_access_files','num_outbound_cmds','is_host_login','is_guest_login','count','serror_rate',
'rerror_rate','same_srv_rate','diff_srv_rate','srv_count','srv_serror_rate','srv_rerror_rate','srv_diff_host_rate',
'dst_host_count','dst_host_srv_count','dst_host_same_srv_rate','dst_host_diff_srv_rate','dst_host_same_src_port_rate',
'dst_host_srv_diff_host_rate','dst_host_serror_rate','dst_host_srv_serror_rate','dst_host_rerror_rate','dst_host_srv_rerror_rate','class'])

print("......Load data......")

XY = convert(df) 

print("......Convert data......")

array = df.values
prex = array[:, :-1]

X = preprocessing.normalize(prex, norm='l2')
Y = array[:, -1]

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state=42) 

knn = KNeighborsClassifier(n_neighbors=3,weights='distance')

print("......Fitting......")
knn.fit(x_train, y_train) 

y_pred = knn.predict(x_test)
y_predict = knn.predict(x_train)

accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: %f' % accuracy)
print(precision_recall_fscore_support(y_test, y_pred, average='macro'))
print("Train*************")
accuracy2 = accuracy_score(y_train, y_predict)
print('Accuracy: %f' % accuracy2)
print(precision_recall_fscore_support(y_train, y_predict, average='macro'))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score


df = pd.read_csv('/home/jinho/Desktop/work/jinho/Learning_ML/dataset/MachineLearningCVE/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv')

df = df[~df.isin([np.nan, np.inf, -np.inf]).any(1)]

print("......Load Data......")
array = df.values
X = array[:, :-1]
Y = array[:, -1]

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state=42) 

knn = KNeighborsClassifier(n_neighbors=1,weights='distance')

print("......Fitting......")
knn.fit(x_train, y_train) 

y_pred = knn.predict(x_test)
y_predict = knn.predict(x_train) 

accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: %f' % accuracy)
print(precision_recall_fscore_support(y_test, y_pred, average='macro'))
print("Train*************")
accuracy2 = accuracy_score(y_train, y_predict)
print('Train Accuracy: %f' % accuracy2)
print(precision_recall_fscore_support(y_train, y_predict, average='macro'))

# %%
df = pd.DataFrame([[np.nan, 2, np.nan, 0], [3, 4, np.nan, 1],
...                    [1,1.5, 2.6, 5], [np.inf, np.nan, np.inf, 7], [3, 4, 6, 5], [np.inf, np.nan, np.inf, 5]])

dx = df[~df.isin([np.nan, np.inf, -np.inf]).any(1)]
print("dd")
print(dx)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score

df = pd.read_csv('/home/jinho/Desktop/work/jinho/Learning_ML/dataset/triple/combined_csv.csv')

df = df[~df.isin([np.nan, np.inf, -np.inf]).any(1)]

print("......Load Data......")
array = df.values
prex = array[:, :-1]

X = preprocessing.normalize(prex, norm='l2')
Y = array[:, -1]

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state=42) 

k_value = 1
knn = KNeighborsClassifier(n_neighbors=k_value,weights='distance')
print("K value =",k_value)

print("......Fitting......")
knn.fit(x_train, y_train) 

print("......Testing......")
y_pred = knn.predict(x_test)
y_predict = knn.predict(x_train)

accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: %f' % accuracy)
print(precision_recall_fscore_support(y_test, y_pred, average='macro'))
print("Train*************")
accuracy2 = accuracy_score(y_train, y_predict)
print('Train Accuracy: %f' % accuracy2)
print(precision_recall_fscore_support(y_train, y_predict, average='macro'))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score


print("......Load Data......") 

df = pd.read_csv('/home/jinho/Desktop/work/jinho/Learning_ML/dataset/triple/combined_csv.csv')

df = df[~df.isin([np.nan, np.inf, -np.inf]).any(1)]
array = df.values
prex = array[:, :-1]

X = preprocessing.normalize(prex, norm='l2')
Y = array[:, -1]


x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state=42) 

knn = KNeighborsClassifier(n_neighbors=5,weights='distance')

print("......Fitting......")
knn.fit(x_train, y_train) 

print("......Testing......")
y_pred = knn.predict(x_test)


accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: %f' % accuracy)
print(precision_recall_fscore_support(y_test, y_pred, average='macro'))

# %%
import csv
import glob
import os
input_path = '/home/jinho/Desktop/work/jinho/Learning_ML/dataset/triple/'
output_file = '/home/jinho/Desktop/work/jinho/merge_csv_files.csv'

print("......Combine csv file......")
is_first_file = True
for input_file in glob.glob(os.path.join(input_path, 'data*')):
    with open(input_file, 'r', newline='') as csv_in_file:
        with open(output_file, 'a', newline='') as csv_out_file:
            freader = csv.reader(csv_in_file)
            fwriter = csv.writer(csv_out_file)
            if is_first_file:
                for row in freader:
                    fwriter.writerow(row)
                is_first_file = False
            else:
                header = next(freader)
                for row in freader:
                    fwriter.writerow(row)

# %%
import os
import glob
import pandas as pd
os.chdir("/home/jinho/Desktop/work/jinho/Learning_ML/dataset/binaryAllNaturalPlusNormalVsAttacks/")

extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score
from scipy.io import arff
from sklearn.metrics import confusion_matrix

print("......Load Data......")
data = arff.loadarff('/home/jinho/Desktop/work/jinho/Learning_ML/dataset/water_final.arff')
df = pd.DataFrame(data[0])

df = df[~df.isin([np.nan, np.inf, -np.inf]).any(1)]

array = df.values
prex = array[:, :-1]
X = preprocessing.normalize(prex, norm='l2')
Y = array[:, -1]
Y=Y.astype('int')


x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state=42) 

k = 5
knn = KNeighborsClassifier(n_neighbors=k,weights='distance')
print("k value = ",k)

print("......Fitting......")
knn.fit(x_train, y_train) 

print("......Testing......")
y_pred = knn.predict(x_test)
y_predict = knn.predict(x_train)

accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: %f' % accuracy)
print(precision_recall_fscore_support(y_test, y_pred, average='macro'))
print("Train*************")
accuracy2 = accuracy_score(y_train, y_predict)
print('Train Accuracy: %f' % accuracy2)
print(precision_recall_fscore_support(y_train, y_predict, average='macro'))

# %%
import pandas as pd
import numpy as np
import arff
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score


print("......Load Data......")
data = arff.load(open('/home/jinho/Desktop/work/jinho/Learning_ML/dataset/gas_final.arff', 'r'))
df = pd.DataFrame(data['data'])

df = df[~df.isin([np.nan, np.inf, -np.inf]).any(1)]

array = df.values
prex = array[:, :-1]
X = preprocessing.normalize(prex, norm='l2')
Y = array[:, -1]
Y=Y.astype('int')


x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state=42) 


k = 7
knn = KNeighborsClassifier(n_neighbors=k,weights='distance')
print("k value = ",k)

print("......Fitting......")
knn.fit(x_train, y_train) 

print("......Testing......")
y_pred = knn.predict(x_test)
y_predict = knn.predict(x_train)

accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: %f' % accuracy)
print(precision_recall_fscore_support(y_test, y_pred, average='macro'))
print("Train*************")
accuracy2 = accuracy_score(y_train, y_predict)
print('Train Accuracy: %f' % accuracy2)
print(precision_recall_fscore_support(y_train, y_predict, average='macro'))

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score

df = pd.read_csv('/home/jinho/Desktop/work/jinho/Learning_ML/dataset/MachineLearningCVE/Wednesday-workingHours.pcap_ISCX.csv')

df = df[~df.isin([np.nan, np.inf, -np.inf]).any(1)]
print("......Load Data......")
array = df.values
prex = array[:, :-1]

X = preprocessing.normalize(prex, norm='l2')
Y = array[:, -1]

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state=42) 

k_value = 3
knn = KNeighborsClassifier(n_neighbors=k_value ,weights='distance')
print("K value =",k_value)

print("......Fitting......")
knn.fit(x_train, y_train) 

print("......Testing......")
y_pred = knn.predict(x_test)
y_predict = knn.predict(x_train)

accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: %f' % accuracy)
print(precision_recall_fscore_support(y_test, y_pred, average='macro'))
print("Train*************")
accuracy2 = accuracy_score(y_train, y_predict)
print('Train Accuracy: %f' % accuracy2)
print(precision_recall_fscore_support(y_train, y_predict, average='macro'))
# Out:
# ......Load Data......
# [[1.04407310e-03 4.99954402e-01 1.30509137e-05 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [3.73706595e-04 4.60168275e-04 1.05675387e-05 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [1.52481258e-05 1.89735202e-04 1.73274157e-06 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  ...
#  [1.26919325e-01 1.79344902e-04 4.37426591e-06 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [2.47779928e-05 4.90246614e-01 2.80505579e-06 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [3.12428480e-04 5.59653726e-01 2.35795079e-05 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]]
